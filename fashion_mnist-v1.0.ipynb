# %%
# Base libs and modules import

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
# Distribution of the dataset into training and test samples

# %%
(x_train, label_train), (x_test, label_test) = fashion_mnist.load_data()

# %%
# Normalizatoin dataset

# %%
x_train = x_train/255
x_test = x_test/255

# %%
# Intro train dataset

# %%
label_name = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
plt.figure(figsize=(15, 15), facecolor='SeaShell')
for i in range(20):
    plt.subplot(5,4,i+1)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.colorbar()
    plt.xlabel(label_name[label_train[i]])

# %%
# Create neural network model

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(2048, activation='relu'),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(256, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(10, activation='softmax')   
])

# %%
# Compile model NN

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              1607680
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 2,822,282
# Trainable params: 2,822,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Learning model NN

# %%
history=model.fit(
    x_train,
    label_train,
    validation_split=0.1,
    batch_size=2048,
    epochs=37)
# Out:
# Epoch 1/37
# 27/27 [==============================] - 0s 17ms/step - loss: 1.4396 - accuracy: 0.5903 - val_loss: 0.8512 - val_accuracy: 0.7500
# Epoch 2/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.6920 - accuracy: 0.7738 - val_loss: 0.5737 - val_accuracy: 0.8058
# Epoch 3/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.5176 - accuracy: 0.8284 - val_loss: 0.4770 - val_accuracy: 0.8395
# Epoch 4/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.4345 - accuracy: 0.8544 - val_loss: 0.4146 - val_accuracy: 0.8582
# Epoch 5/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3926 - accuracy: 0.8657 - val_loss: 0.3845 - val_accuracy: 0.8642
# Epoch 6/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.3628 - accuracy: 0.8739 - val_loss: 0.4055 - val_accuracy: 0.8533
# Epoch 7/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3413 - accuracy: 0.8820 - val_loss: 0.3497 - val_accuracy: 0.8793
# Epoch 8/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3241 - accuracy: 0.8871 - val_loss: 0.3580 - val_accuracy: 0.8710
# Epoch 9/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3093 - accuracy: 0.8907 - val_loss: 0.3344 - val_accuracy: 0.8788
# Epoch 10/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2948 - accuracy: 0.8950 - val_loss: 0.3277 - val_accuracy: 0.8785
# Epoch 11/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2812 - accuracy: 0.8990 - val_loss: 0.3176 - val_accuracy: 0.8848
# Epoch 12/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2656 - accuracy: 0.9052 - val_loss: 0.3253 - val_accuracy: 0.8832
# Epoch 13/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2568 - accuracy: 0.9087 - val_loss: 0.3163 - val_accuracy: 0.8855
# Epoch 14/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2458 - accuracy: 0.9126 - val_loss: 0.3036 - val_accuracy: 0.8870
# Epoch 15/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.2340 - accuracy: 0.9168 - val_loss: 0.3032 - val_accuracy: 0.8908
# Epoch 16/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2222 - accuracy: 0.9210 - val_loss: 0.2995 - val_accuracy: 0.8925
# Epoch 17/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2191 - accuracy: 0.9216 - val_loss: 0.3165 - val_accuracy: 0.8872
# Epoch 18/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2076 - accuracy: 0.9251 - val_loss: 0.3122 - val_accuracy: 0.8868
# Epoch 19/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2057 - accuracy: 0.9258 - val_loss: 0.3027 - val_accuracy: 0.8903
# Epoch 20/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2006 - accuracy: 0.9284 - val_loss: 0.3024 - val_accuracy: 0.8917
# Epoch 21/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.1871 - accuracy: 0.9330 - val_loss: 0.2945 - val_accuracy: 0.8945
# Epoch 22/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.1815 - accuracy: 0.9347 - val_loss: 0.2979 - val_accuracy: 0.8923
# Epoch 23/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1771 - accuracy: 0.9374 - val_loss: 0.3040 - val_accuracy: 0.8930
# Epoch 24/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1718 - accuracy: 0.9384 - val_loss: 0.2930 - val_accuracy: 0.8973
# Epoch 25/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1596 - accuracy: 0.9444 - val_loss: 0.2937 - val_accuracy: 0.8970
# Epoch 26/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1538 - accuracy: 0.9455 - val_loss: 0.3166 - val_accuracy: 0.8935
# Epoch 27/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1558 - accuracy: 0.9456 - val_loss: 0.3096 - val_accuracy: 0.8938
# Epoch 28/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.1466 - accuracy: 0.9481 - val_loss: 0.3031 - val_accuracy: 0.8973
# Epoch 29/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1413 - accuracy: 0.9507 - val_loss: 0.3214 - val_accuracy: 0.8898
# Epoch 30/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1383 - accuracy: 0.9523 - val_loss: 0.3108 - val_accuracy: 0.8960
# Epoch 31/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1303 - accuracy: 0.9551 - val_loss: 0.3263 - val_accuracy: 0.8927
# Epoch 32/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1229 - accuracy: 0.9573 - val_loss: 0.3313 - val_accuracy: 0.8918
# Epoch 33/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1244 - accuracy: 0.9572 - val_loss: 0.3265 - val_accuracy: 0.8955
# Epoch 34/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.1255 - accuracy: 0.9541 - val_loss: 0.3077 - val_accuracy: 0.8993
# Epoch 35/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1144 - accuracy: 0.9599 - val_loss: 0.3261 - val_accuracy: 0.8965
# Epoch 36/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1081 - accuracy: 0.9627 - val_loss: 0.3418 - val_accuracy: 0.8950
# Epoch 37/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1071 - accuracy: 0.9628 - val_loss: 0.3262 - val_accuracy: 0.8990

# %%
# Model results

# %%
results = model.evaluate(x_test, label_test)
print(f'Model Loss: {round(results[0], 3)} \nModel Accuracy: {round(results[1], 3)}')
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3371 - accuracy: 0.9012
# Model Loss: 0.337
# Model Accuracy: 0.901

# %%
# Plot train and validation data

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 12))


axes[0].set_title('Train metrics Loss & Val_Loss')
axes[0].plot(history.history['loss'], label='Loss', color='SteelBlue')
axes[0].plot(history.history['val_loss'], label='Val_loss', marker='o', linestyle='--', color='SteelBlue')
axes[0].legend()

axes[1].set_title('Train metrics Accuracy & Val_Accuracy')
axes[1].plot(history.history['accuracy'], label='Accuracy', color='DarkOrange')
axes[1].plot(history.history['val_accuracy'], label='Val_Accuracy', marker='o', linestyle='--', color='DarkOrange')
axes[1].legend()

plt.show()

# %%
# Predict model NN

# %%
predict=model.predict(x_test)

# %%
random_indexes = np.random.choice(len(x_test), size=16, replace=False)

plt.figure(figsize=(12, 10), facecolor='SeaShell')

for i in range(len(random_indexes)):
    
    index = random_indexes[i]
    
    pred_label = label_name[np.argmax(predict[index])]
    true_label = label_name[label_test[index]]
    
    if pred_label == true_label:
        color = "ForestGreen"
    else:
        color = "FireBrick"
    
    plt.subplot(4,4,i+1)
    plt.imshow(x_test[index], cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.colorbar()
    
    plt.xlabel("{} [{}]".format(true_label, pred_label), color=color)
