# %%
# Base libs and modules import

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
# Distribution of the dataset into training and test samples

# %%
(x_train, label_train), (x_test, label_test) = fashion_mnist.load_data()

# %%
# Normalizatoin dataset

# %%
x_train = x_train/255
x_test = x_test/255

# %%
# Intro train dataset

# %%
label_name = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
plt.figure(figsize=(15, 15), facecolor='SeaShell')
for i in range(20):
    plt.subplot(5,4,i+1)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.colorbar()
    plt.xlabel(label_name[label_train[i]])

# %%
# Create neural network model

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(2048, activation='relu'),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(256, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(10, activation='softmax')   
])

# %%
# Compile model NN

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 2048)              1607680
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 2,822,282
# Trainable params: 2,822,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Learning model NN

# %%
history=model.fit(
    x_train,
    label_train,
    validation_split=0.1,
    batch_size=2048,
    epochs=37)
# Out:
# Epoch 1/37
# 27/27 [==============================] - 0s 17ms/step - loss: 1.5430 - accuracy: 0.5338 - val_loss: 0.9459 - val_accuracy: 0.6900
# Epoch 2/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.7637 - accuracy: 0.7483 - val_loss: 0.6135 - val_accuracy: 0.7892
# Epoch 3/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.5528 - accuracy: 0.8127 - val_loss: 0.5020 - val_accuracy: 0.8323
# Epoch 4/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.4570 - accuracy: 0.8459 - val_loss: 0.4480 - val_accuracy: 0.8460
# Epoch 5/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.4120 - accuracy: 0.8572 - val_loss: 0.4097 - val_accuracy: 0.8588
# Epoch 6/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.3736 - accuracy: 0.8705 - val_loss: 0.3810 - val_accuracy: 0.8688
# Epoch 7/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3486 - accuracy: 0.8781 - val_loss: 0.3556 - val_accuracy: 0.8718
# Epoch 8/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3252 - accuracy: 0.8853 - val_loss: 0.3407 - val_accuracy: 0.8748
# Epoch 9/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.3082 - accuracy: 0.8912 - val_loss: 0.3445 - val_accuracy: 0.8735
# Epoch 10/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2926 - accuracy: 0.8966 - val_loss: 0.3385 - val_accuracy: 0.8752
# Epoch 11/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2787 - accuracy: 0.9016 - val_loss: 0.3368 - val_accuracy: 0.8747
# Epoch 12/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2749 - accuracy: 0.9009 - val_loss: 0.3219 - val_accuracy: 0.8827
# Epoch 13/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2545 - accuracy: 0.9089 - val_loss: 0.3140 - val_accuracy: 0.8840
# Epoch 14/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.2510 - accuracy: 0.9103 - val_loss: 0.3257 - val_accuracy: 0.8812
# Epoch 15/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.2386 - accuracy: 0.9154 - val_loss: 0.3182 - val_accuracy: 0.8873
# Epoch 16/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2260 - accuracy: 0.9191 - val_loss: 0.3056 - val_accuracy: 0.8903
# Epoch 17/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2174 - accuracy: 0.9229 - val_loss: 0.3244 - val_accuracy: 0.8867
# Epoch 18/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2202 - accuracy: 0.9219 - val_loss: 0.3021 - val_accuracy: 0.8917
# Epoch 19/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2008 - accuracy: 0.9289 - val_loss: 0.3246 - val_accuracy: 0.8845
# Epoch 20/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.2001 - accuracy: 0.9279 - val_loss: 0.3216 - val_accuracy: 0.8877
# Epoch 21/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1905 - accuracy: 0.9327 - val_loss: 0.3170 - val_accuracy: 0.8885
# Epoch 22/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1825 - accuracy: 0.9352 - val_loss: 0.3124 - val_accuracy: 0.8918
# Epoch 23/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1775 - accuracy: 0.9378 - val_loss: 0.3151 - val_accuracy: 0.8933
# Epoch 24/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1738 - accuracy: 0.9383 - val_loss: 0.3031 - val_accuracy: 0.8932
# Epoch 25/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.1602 - accuracy: 0.9448 - val_loss: 0.3027 - val_accuracy: 0.8965
# Epoch 26/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.1567 - accuracy: 0.9451 - val_loss: 0.2988 - val_accuracy: 0.8967
# Epoch 27/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1482 - accuracy: 0.9480 - val_loss: 0.3127 - val_accuracy: 0.8935
# Epoch 28/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1424 - accuracy: 0.9511 - val_loss: 0.3152 - val_accuracy: 0.8962
# Epoch 29/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1409 - accuracy: 0.9516 - val_loss: 0.3307 - val_accuracy: 0.8920
# Epoch 30/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.1383 - accuracy: 0.9521 - val_loss: 0.3296 - val_accuracy: 0.8900
# Epoch 31/37
# 27/27 [==============================] - 0s 13ms/step - loss: 0.1378 - accuracy: 0.9513 - val_loss: 0.3263 - val_accuracy: 0.8910
# Epoch 32/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1302 - accuracy: 0.9557 - val_loss: 0.3174 - val_accuracy: 0.8988
# Epoch 33/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1213 - accuracy: 0.9586 - val_loss: 0.3370 - val_accuracy: 0.8933
# Epoch 34/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1234 - accuracy: 0.9568 - val_loss: 0.3290 - val_accuracy: 0.8988
# Epoch 35/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1210 - accuracy: 0.9574 - val_loss: 0.3578 - val_accuracy: 0.8917
# Epoch 36/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1229 - accuracy: 0.9559 - val_loss: 0.3176 - val_accuracy: 0.8988
# Epoch 37/37
# 27/27 [==============================] - 0s 12ms/step - loss: 0.1041 - accuracy: 0.9653 - val_loss: 0.3170 - val_accuracy: 0.9013

# %%
# Model results

# %%
results = model.evaluate(x_test, label_test)
print(f'Model Loss: {round(results[0], 3)} \nModel Accuracy: {round(results[1], 3)}')
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3287 - accuracy: 0.9000
# Model Loss: 0.329
# Model Accuracy: 0.9

# %%
# Plot train and validation data

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 12))


axes[0].set_title('Train metrics Loss & Val_Loss')
axes[0].plot(history.history['loss'], label='Loss', color='SteelBlue')
axes[0].plot(history.history['val_loss'], label='Val_loss', marker='o', linestyle='--', color='SteelBlue')
axes[0].legend()

axes[1].set_title('Train metrics Accuracy & Val_Accuracy')
axes[1].plot(history.history['accuracy'], label='Accuracy', color='DarkOrange')
axes[1].plot(history.history['val_accuracy'], label='Val_Accuracy', marker='o', linestyle='--', color='DarkOrange')
axes[1].legend()

plt.show()

# %%
# Predict model NN

# %%
predict=model.predict(x_test)

# %%
random_indexes = np.random.choice(len(x_test), size=20, replace=False)

plt.figure(figsize=(15, 15), facecolor='SeaShell')

for i in range(len(random_indexes)):
    
    index = random_indexes[i]
    
    pred_label = label_name[np.argmax(predict[index])]
    true_label = label_name[label_test[index]]
    
    if pred_label == true_label:
        color = "ForestGreen"
    else:
        color = "FireBrick"
    
    plt.subplot(5,4,i+1)
    plt.imshow(x_test[index], cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.colorbar()
    
    plt.xlabel("{} [{}]".format(true_label, pred_label), color=color)
